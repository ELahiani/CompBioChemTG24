# %% [markdown]
# ### Command Line Basics Assignment
#
# ---

# %% [markdown]
# 1. Mount this notebook to your google drive then navigate to the shared TechGirl EMMI google drive. Add however many code cells needed to complete this section.
#
# *Hint: you need to generate a shortcut for the shared drive to your google drive before being able to navigate to a shared folder.*

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Import any commands to utilize colab for command line operation
# Make sure that automagic is turned ON, run until print says "Automagic is ON, % previs IS NOT needed for line magics"

# %automagic
# Out:
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# **2**. List all contents of the main TechGirls EMMI google drive.
#
# > Ajouter une citation

# %% [markdown]
# 3. Navigate to your student directory

# %% [markdown]
# 4. Create a directory called "CommandLine_Assignment" within your student directory

# %% [markdown]
# 5. Generate a file with the title as your name. *Example Amanda.txt*

# %% [markdown]
# 6. Move your text file to the "CommandLine_Assignment" directory.

# %% [markdown]
# 7. Print the path to the directory you just generated
